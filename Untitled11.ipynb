# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN,Dense, Embedding ,Dropout

# %% [markdown]
# # **Unzip File**

# %%
# !unzip /content/twitter_training.csv.zip
# Out:
# Archive:  /content/twitter_training.csv.zip
# replace twitter_training.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# # **Data Preprocessing**

# %%
df=pd.read_csv("/content/twitter_training.csv")

# %%
df.columns
# Out:
# Index(['2401', 'Borderlands', 'Positive',
#        'im getting on borderlands and i will murder you all ,'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74681 entries, 0 to 74680
# Data columns (total 4 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   2401                                                   74681 non-null  int64
#  1   Borderlands                                            74681 non-null  object
#  2   Positive                                               74681 non-null  object
#  3   im getting on borderlands and i will murder you all ,  73995 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ MB

# %%
df.head(20)
# Out:
#     2401  Borderlands  Positive  \
# 0   2401  Borderlands  Positive
# 1   2401  Borderlands  Positive
# 2   2401  Borderlands  Positive
# 3   2401  Borderlands  Positive
# 4   2401  Borderlands  Positive
# 5   2402  Borderlands  Positive
# 6   2402  Borderlands  Positive
# 7   2402  Borderlands  Positive
# 8   2402  Borderlands  Positive
# 9   2402  Borderlands  Positive
# 10  2402  Borderlands  Positive
# 11  2403  Borderlands   Neutral
# 12  2403  Borderlands   Neutral
# 13  2403  Borderlands   Neutral
# 14  2403  Borderlands   Neutral
# 15  2403  Borderlands   Neutral
# 16  2403  Borderlands   Neutral
# 17  2404  Borderlands  Positive
# 18  2404  Borderlands  Positive
# 19  2404  Borderlands  Positive
#
#    im getting on borderlands and i will murder you all ,
# 0   I am coming to the borders and I will kill you...
# 1   im getting on borderlands and i will kill you ...
# 2   im coming on borderlands and i will murder you...
# ...

# %%
df.tail(10)
# Out:
#        2401 Borderlands  Positive  \
# 74671  9199      Nvidia  Positive
# 74672  9199      Nvidia  Positive
# 74673  9199      Nvidia  Positive
# 74674  9199      Nvidia  Positive
# 74675  9200      Nvidia  Positive
# 74676  9200      Nvidia  Positive
# 74677  9200      Nvidia  Positive
# 74678  9200      Nvidia  Positive
# 74679  9200      Nvidia  Positive
# 74680  9200      Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 74671  Let no elite go unnoticed... NVIDIA Highlights...
# 74672  Let no elim go unnoticed.... NVIDIA Highlights...
# 74673  Let a no information elim that go unnoticed......
# 74674  <unk> my elim be no.... NVIDIA Highlights Pict...
# 74675  Just realized the windows partition of my Mac ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# 74678  Just realized the windows partition of my Mac ...
# 74679  Just realized between the windows partition of...
# ...

# %%
df.isnull().sum()
# Out:
# 2401                                                       0
# Borderlands                                                0
# Positive                                                   0
# im getting on borderlands and i will murder you all ,    686
# dtype: int64

# %%
df.isna().sum()
# Out:
# 2401                                                       0
# Borderlands                                                0
# Positive                                                   0
# im getting on borderlands and i will murder you all ,    686
# dtype: int64

# %%
column_to_fill = 'im getting on borderlands and i will murder you all ,'
mode_value = df[column_to_fill].mode()[0]
df[column_to_fill] = df[column_to_fill].fillna(mode_value)

# %%
df.isnull().sum()
# Out:
# 2401                                                     0
# Borderlands                                              0
# Positive                                                 0
# im getting on borderlands and i will murder you all ,    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# 2401                                                     0
# Borderlands                                              0
# Positive                                                 0
# im getting on borderlands and i will murder you all ,    0
# dtype: int64

# %% [markdown]
# # **Data Split**

# %%
y=df['Positive']
x=df['im getting on borderlands and i will murder you all ,']

# %%
print(y.head())
# Out:
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Positive
# 4    Positive
# Name: Positive, dtype: object

# %% [markdown]
# # **Label Encoding**
#
# ---

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

y = encoder.fit_transform(y)

# %%
print(y)
# Out:
# [3 3 3 ... 3 3 3]

# %%
print(encoder.classes_)
# Out:
# [0 1 2 3]

# %% [markdown]
# # **Tokenization**

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
token=Tokenizer(num_words=5000)
token.fit_on_texts(x)
sq = token.texts_to_sequences(x)

# %% [markdown]
# # **Padding**

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_pad=pad_sequences(sq,maxlen=20)

# %%
model = Sequential([

    Embedding(input_dim=5000, output_dim=64),

    SimpleRNN(64),
    Dropout(0.5),

    Dense(4, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.build(input_shape=(None,20))

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)         │ (None, 20, 64)         │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_9 (SimpleRNN)        │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 985,550 (3.76 MB)
#  Trainable params: 328,516 (1.25 MB)
# ...

# %%
print(x_pad.dtype)
print(y.dtype)
# Out:
# int32
# int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x_pad,
    y,
    test_size=0.2,
    random_state=42
)

# %%
model.fit(X_train,y_train,epochs=10,validation_data=(X_test,y_test) )
# Out:
# Epoch 1/10
# 1867/1867 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.6521 - loss: 0.8861 - val_accuracy: 0.6961 - val_loss: 0.7780
# Epoch 2/10
# 1867/1867 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - accuracy: 0.7882 - loss: 0.5713 - val_accuracy: 0.7531 - val_loss: 0.6515
# Epoch 3/10
# 1867/1867 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.8405 - loss: 0.4301 - val_accuracy: 0.7629 - val_loss: 0.6791
# Epoch 4/10
# 1867/1867 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.8684 - loss: 0.3513 - val_accuracy: 0.7570 - val_loss: 0.6987
# Epoch 5/10
# 1867/1867 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.8860 - loss: 0.3059 - val_accuracy: 0.7671 - val_loss: 0.7065
# Epoch 6/10
# 1867/1867 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.8981 - loss: 0.2724 - val_accuracy: 0.7677 - val_loss: 0.7425
# Epoch 7/10
# 1867/1867 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9072 - loss: 0.2479 - val_accuracy: 0.7682 - val_loss: 0.7871
# Epoch 8/10
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print( "Loss :",loss)

print("Accuracy:", accuracy)
# Out:
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7574 - loss: 0.8898
# Loss : 0.8897874355316162
# Accuracy: 0.757381021976471

# %% [markdown]
# # **Testing Phase**

# %%
labels = {
    0: "Irrelevant",
    1: "Negative",
    2: "Neutral",
    3: "Positive"
}

# %%
text = ["I am  ok"]

seq = token.texts_to_sequences(text)

pad = pad_sequences(seq, maxlen=20)

pred = model.predict(pad)

predicted_class = np.argmax(pred)

print("Predicted Sentiment:",
      labels[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted Sentiment: Neutral
